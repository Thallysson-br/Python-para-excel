# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#add your custom working directory
# %cd /content/gdrive/Shareddrives/Friends&Co/Novo Python para Excel
# Out:
# /content/gdrive/Shareddrives/Friends&Co/Novo Python para Excel

# %%
# !pwd
# Out:
# /content/gdrive/Shareddrives/Friends&Co/Novo Python para Excel

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/Shareddrives/Friends&Co/Novo Python para Excel/.git/

# %%
username ='davimart'
token ='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'
repo_username ='Thallysson-br'
repo='Python-para-excel'

# %%
# !git remote add origin https://{token}@github.com/{repo_username}/{repo}.git
# !git remote -v
# Out:
# origin	https://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@github.com/Thallysson-br/Python-para-excel.git (fetch)
# origin	https://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@github.com/Thallysson-br/Python-para-excel.git (push)

# %%
# !git remote add origin https://davimart:155*Civil@github.com/Thallysson-br/Python-para-excel.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://davimart:155*Civil@github.com/Thallysson-br/Python-para-excel.git (fetch)
# origin	https://davimart:155*Civil@github.com/Thallysson-br/Python-para-excel.git (push)

# %%
# !git config --global user.email 'martdavi@gmail.com'
# !git config --global user.name 'davimart'

# %%
# !git pull https://github.com/Thallysson-br/Python-para-excel.git
# Out:
# From https://github.com/Thallysson-br/Python-para-excel
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
# !git add .
# !git commit -m 'Google Colab arquivo novo'
# Out:
# [master c21fbdf] Google Colab arquivo novo
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 Friends&Co.ipynb
#  rewrite colabGitWorkflow.ipynb (89%)

# %%
# !git br
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://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@github.com/Thallysson-br/Python-para-excel.git'
